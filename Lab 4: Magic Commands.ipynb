# %%
# %fs
ls

# %%
# %sh
# present working directory
pwd

# %%
# %run
# execute another notebook

# %%
# %python
print("hello world")

# %%
# %scala

print("Hello from Python!")
a = 5
b = 3
sum_ = a + b
print(f"The sum of {a} and {b} is {sum_}")

# %%
# %sql
select * from table;

# %%
# %r
x <- 10
print(x)

# %% [markdown]
# # Hello World

# %%
# %time print("Hello")

# %%
# %fs
ls /

# %%
# %fs
ls dbfs:/databricks-datasets/

# %%
# %fs
ls dbfs:/databricks-datasets/README.md
